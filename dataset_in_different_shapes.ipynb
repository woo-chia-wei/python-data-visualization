# %% [markdown]
# ## Load packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## XOR Dataset

# %%
################
# Configuration
################
size = 500

##########################
# Create 2D-coordinates
##########################
X = np.vstack((np.random.rand(size, 2), 
               np.random.rand(size, 2) + (-1, -1), 
               np.random.rand(size, 2) + (-1, 0), 
               np.random.rand(size, 2) + (0, -1)))

#################
# Create labels
#################
Y = np.concatenate((np.repeat(0, size * 2),
               np.repeat(1, size * 2)))

#########################################################
# Combine X and Y to be training set with shuffled order
#########################################################
training = np.column_stack((X, Y))
np.random.shuffle(training)

#####################
# Create scatterplot
#####################
colors = ['blue', 'red']
plt.scatter(training[:, 0], training[:, 1], c=training[:, 2], alpha=0.3, cmap=ListedColormap(colors))
plt.axis('equal')
plt.show()

##########################
# Print first 10 records
##########################
print(training[:10])
# Out:
# [[-0.84565878  0.03018643  1.        ]
#  [-0.68358077  0.97638185  1.        ]
#  [-0.57064719 -0.88080819  0.        ]
#  [-0.33989228 -0.82232723  0.        ]
#  [ 0.37424841 -0.39856998  1.        ]
#  [ 0.09994106  0.27018963  0.        ]
#  [ 0.59678422  0.97876568  0.        ]
#  [-0.36191011  0.23816477  1.        ]
#  [-0.22667664 -0.25817056  0.        ]
#  [-0.04312067  0.27309149  1.        ]]

# %% [markdown]
# ## Donut Dataset

# %%
################
# Configuration
################
size = 400
delta = 1

##########################
# Create 2D-coordinates
##########################
def donut_data(size, radius, delta):
    radii = np.interp(np.random.rand(size), [0, 1], [radius-delta, radius+delta])
    angles = np.interp(np.random.rand(size), [0, 1], [-np.pi, np.pi])
    return np.column_stack([radii * np.cos(angles), radii * np.sin(angles)]) 

X = np.vstack((donut_data(size, 10, 1),
               donut_data(size, 20, 1)))

#################
# Create labels
#################
Y = np.concatenate((np.repeat(0, size),
                    np.repeat(1, size)))

#########################################################
# Combine X and Y to be training set with shuffled order
#########################################################
training = np.column_stack((X, Y))
np.random.shuffle(training)

#####################
# Create scatterplot
#####################
colors = ['blue', 'red']
plt.scatter(training[:, 0], training[:, 1], c=training[:, 2], alpha=0.3, cmap=ListedColormap(colors))
plt.axis('equal')
plt.show()

##########################
# Print first 10 records
##########################
print(training[:10])
# Out:
# [[ -8.97494302  -1.53109667   0.        ]
#  [ -7.7852721   -5.00590525   0.        ]
#  [  6.94260915  -7.938025     0.        ]
#  [ -5.50853825  18.96634602   1.        ]
#  [  9.44691387  -4.44092681   0.        ]
#  [ -5.70131629  -7.74769161   0.        ]
#  [-19.12193911  -4.91326858   1.        ]
#  [  3.08429978  -8.64865024   0.        ]
#  [ -0.16791577 -20.67471209   1.        ]
#  [  8.88048824   5.26803222   0.        ]]

# %% [markdown]
# ## Spiral Dataset

# %%
################
# Configuration
################
a = 1
b = 1
size = 120
delta = 0.15

##########################
# Create 2D-coordinates
##########################
def spiral_data(a, b, size, delta, rotation):
    
    # Polar coordinates
    angles = np.interp(np.random.rand(size), [0, 1], [np.pi/10, np.pi/3])
    radii = a * np.exp(b * angles) - a
    x = radii * np.cos(angles)
    y = radii * np.sin(angles)
    
    # Create random neighbours
    r = np.interp(np.random.rand(size), [0, 1], [0, delta])
    t = np.interp(np.random.rand(size), [0, 1], [0, np.pi * 2])
    x, y = x + r * np.cos(t), y + r * np.sin(t)
    
    # Rotate all the points
    x, y = x * np.cos(rotation) - y * np.sin(rotation), x * np.sin(rotation) + y * np.cos(rotation)
    return np.column_stack((x, y))

X = np.vstack((spiral_data(a, b, size, delta, np.pi / 3 * 0),
               spiral_data(a, b, size, delta, np.pi / 3 * 2),
               spiral_data(a, b, size, delta, np.pi / 3 * 4),
               spiral_data(a, b, size, delta, np.pi / 3 * 1),
               spiral_data(a, b, size, delta, np.pi / 3 * 3),
               spiral_data(a, b, size, delta, np.pi / 3 * 5)))

#################
# Create labels
#################
Y = np.concatenate((np.repeat(0, size * 3),
                    np.repeat(1, size * 3)))

#########################################################
# Combine X and Y to be training set with shuffled order
#########################################################
training = np.column_stack((X, Y))
np.random.shuffle(training)

#####################
# Create scatterplot
#####################
colors = ['blue', 'red']
plt.scatter(training[:, 0], training[:, 1], c=training[:, 2], alpha=0.2, cmap=ListedColormap(colors))
plt.axis('equal')
plt.show()

##########################
# Print first 10 records
##########################
print(training[:10])
# Out:
# [[ 0.6149148   0.37804514  0.        ]
#  [-0.04376525 -0.68638285  0.        ]
#  [ 0.67933139  0.71067356  0.        ]
#  [ 0.7911224  -1.60669719  0.        ]
#  [-0.45420211  0.32384424  0.        ]
#  [-0.48232258  1.32901452  1.        ]
#  [-0.03616758 -0.58515076  0.        ]
#  [-0.58326558 -0.48762158  1.        ]
#  [ 1.56053236 -0.28142682  1.        ]
#  [-0.46068374 -0.20675679  1.        ]]
